# %% [markdown]
# 1. Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (2.5 points)
# 2. Print all the teams which have started playing between 1930-1980. (5 points)
# 3. Print the list of teams which came Top 5 in terms of points (2.5 points)
# 4. Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same   function, find the team which has maximum and minimum goal difference. (5 points)
#     Goal_diff_count = GoalsFor - GoalsAgainst
#
# 5. Create a new column with name “Winning Percent” and append it to the data set (5 points)
#      Percentage of Winning = (GamesWon / GamesPlayed)*100
#      If there are any numerical error, replace it with 0%
#      Print the top 5 teams which has the highest Winning percentage
#
# 6. Group teams based on their “Best position” and print the sum of their points for all positions (5 points)
#     Eg: Best Position                Points
#
#         1                              25000
#
#         2                              7000

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q1. Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data.

# %%
mydata = pd.read_csv('Laliga.csv')

# %%
mydata.replace('-','0',inplace =True)

# %%
mydata.columns = ['Pos','Team', 'Seasons', 'Points', 'GamesPlayed','GamesWon','GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion', 'Runnerup', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut', 'Since/LastApp', 'BestPosition']

# %%
mydata.set_index('Pos', inplace=True)

# %%
mydata.drop('Pos',inplace=True)

# %%
mydata.head()
# Out:
#                 Team Seasons Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# Pos
# 1        Real Madrid      86   4385        2762     1647        552       563
# 2          Barcelona      86   4262        2762     1581        573       608
# 3    Atletico Madrid      80   3442        2614     1241        598       775
# 4           Valencia      82   3386        2664     1187        616       861
# 5    Athletic Bilbao      86   3368        2762     1209        633       920
#
#     GoalsFor GoalsAgainst Champion Runnerup Third Fourth Fifth Sixth   T  \
# Pos
# 1       5947         3140       33       23     8      8     3     4  79
# 2       5900         3114       25       25    12     12     4     6  83
# 3       4534         3309       10        8    16      9     7     6  56
# 4       4398         3469        6        6    10     11    10     7  50
# 5       4631         3700        8        7    10      5     8    10  49
#
#        Debut Since/LastApp BestPosition
# Pos
# ...

# %% [markdown]
# Q2: Print all the teams which have started playing between 1930-1980. (5 points)

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 1 to 61
# Data columns (total 19 columns):
# Team             61 non-null object
# Seasons          61 non-null object
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runnerup         61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null object
# dtypes: object(19)
# memory usage: 9.5+ KB

# %%
mydata['Debut'] = mydata['Debut'].astype(str).str[:4].astype(int)
mydata['Since/LastApp'] = mydata['Since/LastApp'].astype(str).str[:4].astype(int)

# %%
mydata['Team'].astype(str)
mydata['Seasons'] = pd.to_numeric(mydata["Seasons"], errors = 'ignore')
mydata['Points'] = pd.to_numeric(mydata['Points'], errors='ignore')
mydata['GamesPlayed'] = pd.to_numeric(mydata["GamesPlayed"], errors = 'ignore')
mydata['GamesWon'] = pd.to_numeric(mydata['GamesWon'], errors='ignore')
mydata['GamesDrawn'] = pd.to_numeric(mydata["GamesDrawn"], errors = 'ignore')
mydata['GamesLost'] = pd.to_numeric(mydata['GamesLost'], errors='ignore')
mydata['GoalsFor'] = pd.to_numeric(mydata["GoalsFor"], errors = 'ignore')
mydata['GoalsAgainst'] = pd.to_numeric(mydata['GoalsAgainst'], errors='ignore')
mydata['Champion'] = pd.to_numeric(mydata["Champion"], errors = 'ignore')
mydata['Runnerup'] = pd.to_numeric(mydata['Runnerup'], errors='ignore')
mydata['Third'] = pd.to_numeric(mydata["Third"], errors = 'ignore')
mydata['Fourth'] = pd.to_numeric(mydata['Fourth'], errors='ignore')
mydata['Fifth'] = pd.to_numeric(mydata['Fifth'], errors='ignore')
mydata['Sixth'] = pd.to_numeric(mydata["Sixth"], errors = 'ignore')
mydata['T'] = pd.to_numeric(mydata['T'], errors='ignore')
mydata['Debut'] = pd.to_numeric(mydata["Debut"], errors = 'ignore')
mydata['Since/LastApp'] = pd.to_numeric(mydata['Since/LastApp'], errors='ignore')
mydata['BestPosition'] = pd.to_numeric(mydata['BestPosition'], errors='ignore')

# %%
mydata['Team'][(mydata['Debut']>1930) & (mydata['Debut']<1980)]
# Out:
# Pos
# 4                Valencia
# 6                 Sevilla
# 9                Zaragoza
# 10             Real Betis
# 11    Deportivo La Coruna
# 12             Celta Vigo
# 13             Valladolid
# 15         Sporting Gijon
# 16                Osasuna
# 17                 Malaga
# 18                 Oviedo
# 19               Mallorca
# 20             Las Palmas
# 22                Granada
# 23         Rayo Vallecano
# 24                  Elche
# 26               Hercules
# 27               Tenerife
# 28                 Murcia
# 30                Levante
# 31              Salamanca
# 32               Sabadell
# 33                  Cadiz
# 35              Castellon
# 38                Cordoba
# 40             Recreativo
# 41              Burgos CF
# 42             Pontevedra
# 47              Gimnastic
# 50               Alcoyano
# 51                   Jaen
# 53             AD Almeria
# 55                 Lleida
# 58                 Condal
# 59        Atletico Tetuan
# ...

# %% [markdown]
# Q3 Print the list of teams which came Top 5 in terms of points (2.5 points)

# %%
mydata.sort_values(by = 'Points', ascending=False, inplace =True)

# %%
mydata.head(5)
# Out:
#                 Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# Pos
# 1        Real Madrid       86    4385         2762      1647         552
# 2          Barcelona       86    4262         2762      1581         573
# 3    Atletico Madrid       80    3442         2614      1241         598
# 4           Valencia       82    3386         2664      1187         616
# 5    Athletic Bilbao       86    3368         2762      1209         633
#
#      GamesLost  GoalsFor  GoalsAgainst  Champion  Runnerup  Third  Fourth  \
# Pos
# 1          563      5947          3140        33        23      8       8
# 2          608      5900          3114        25        25     12      12
# 3          775      4534          3309        10         8     16       9
# 4          861      4398          3469         6         6     10      11
# 5          920      4631          3700         8         7     10       5
#
#      Fifth  Sixth   T  Debut  Since/LastApp  BestPosition
# Pos
# ...

# %% [markdown]
# Q4 Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points) Goal_diff_count = GoalsFor - GoalsAgainst

# %%
def Goal_diff_count(x):
    x['Goalsdiff'] = x['GoalsFor'] - x['GoalsAgainst']
    return(x['Team'],x['Goalsdiff'])
    

Gdiff = pd.DataFrame(Goal_diff_count(mydata))
gdiff_data = Gdiff.T
print(gdiff_data.max(),gdiff_data.min())
# Out:
# Team         Zaragoza
# Goalsdiff        2807
# dtype: object Team         AD Almeria
# Goalsdiff          -525
# dtype: object

# %% [markdown]
# Q5 Create a new column with name “Winning Percent” and append it to the data set (5 points) Percentage of Winning = (GamesWon / GamesPlayed)*100 If there are any numerical error, replace it with 0% Print the top 5 teams which has the highest Winning percentage

# %%
def per_win(x):
    x['Per_of_win'] = (x['GamesWon']/x['GamesPlayed'])*100
    return(x.head())

per_win(mydata)
mydata.fillna(value=0)
mydata.head(5)
# Out:
#                 Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# Pos
# 1        Real Madrid       86    4385         2762      1647         552
# 2          Barcelona       86    4262         2762      1581         573
# 3    Atletico Madrid       80    3442         2614      1241         598
# 4           Valencia       82    3386         2664      1187         616
# 5    Athletic Bilbao       86    3368         2762      1209         633
#
#      GamesLost  GoalsFor  GoalsAgainst  Champion  ...  Third  Fourth  Fifth  \
# Pos                                               ...
# 1          563      5947          3140        33  ...      8       8      3
# 2          608      5900          3114        25  ...     12      12      4
# 3          775      4534          3309        10  ...     16       9      7
# 4          861      4398          3469         6  ...     10      11     10
# 5          920      4631          3700         8  ...     10       5      8
#
# ...

# %% [markdown]
# Q6 Group teams based on their “Best position” and print the sum of their points for all positions (5 points) Eg: Best Position Points
#
#  1                              25000
#
#  2                              7000

# %%
group_pts = mydata.groupby('BestPosition')
group_new = group_pts.sum()
group_new['Points']
# Out:
# BestPosition
# 1     27933
# 2      6904
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 20       34
# Name: Points, dtype: int64
